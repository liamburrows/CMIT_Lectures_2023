# %%
import torch
from skimage import io, transform
import numpy as np
import torchvision.transforms as T
import matplotlib.pyplot as plt
from PIL import Image

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## UNET
# - UNet is a particular type of CNN, named after its U shape
# - [Original paper](https://arxiv.org/pdf/1505.04597.pdf)
# <p align="center">
# <img src="unet.png" width="1000" title="Image." >
# </p>

# %%
class conv_block(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size = 3, padding = 1):
        super().__init__()

        self.activation_fn = nn.ReLU()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size = kernel_size, padding = padding)
        self.bn1 = nn.BatchNorm2d(out_channels)

        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size = kernel_size, padding = padding)
        self.bn2 = nn.BatchNorm2d(out_channels)
    
    def forward(self, inputs):
        x = self.conv1(inputs)
        x = self.bn1(x)
        x = self.activation_fn(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.activation_fn(x)
        return x
    
class down_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = conv_block(in_channels, out_channels)
        self.pool = nn.MaxPool2d((2,2))

    def forward(self, inputs):
        x = self.conv(inputs)
        p = self.pool(x)
        return x,p

class up_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels, out_channels, kernel_size = 2, stride = 2, padding = 0)
        self.conv = conv_block(out_channels+out_channels, out_channels)
    
    def forward(self, inputs, skip):
        x = self.up(inputs)
        x = torch.cat([x, skip], axis=1)
        x = self.conv(x)
        return x


class UNet(nn.Module):

    def __init__(self, in_channels=3, out_channels = 1, f = [64,128,256,512,1024]):
        super().__init__()

        self.encoder1 = down_block(in_channels, f[0])
        self.encoder2 = down_block(f[0],f[1])
        self.encoder3 = down_block(f[1],f[2])
        self.encoder4 = down_block(f[2],f[3])

        self.bottleneck = conv_block(f[3],f[4])

        self.decoder1 = up_block(f[4],f[3])
        self.decoder2 = up_block(f[3],f[2])
        self.decoder3 = up_block(f[2],f[1])
        self.decoder4 = up_block(f[1],f[0])

        self.outputs = nn.Conv2d(f[0], out_channels, kernel_size = 1, padding = 0)
        self.sigmoid_layer = nn.Sigmoid()

    def forward(self, inputs):
        c1, p1 = self.encoder1(inputs)
        c2, p2 = self.encoder2(p1)
        c3, p3 = self.encoder3(p2)
        c4, p4 = self.encoder4(p3)

        bn = self.bottleneck(p4)

        d1 = self.decoder1(bn, c4)
        d2 = self.decoder2(d1, c3)
        d3 = self.decoder3(d2, c2)
        d4 = self.decoder4(d3, c1)

        outputs = self.outputs(d4)
        outputs = self.sigmoid_layer(outputs)
        
        plot = True
        if plot:
            print('Input shape', inputs.shape)
            print('After layer 1', p1.shape)
            print('After layer 2', p2.shape)
            print('After layer 3', p3.shape)
            print('After layer 4', p4.shape)
            print('After bn', bn.shape)
            print('After layer 6', d1.shape)
            print('After layer 7', d2.shape)
            print('After layer 8', d3.shape)
            print('After layer 9', d4.shape)
            print('Output shape', outputs.shape)

        return outputs
UNet = UNet()

x = torch.zeros([1,3,256,256])
y = UNet(x)
# Out:
# Input shape torch.Size([1, 3, 256, 256])
# After layer 1 torch.Size([1, 64, 128, 128])
# After layer 2 torch.Size([1, 128, 64, 64])
# After layer 3 torch.Size([1, 256, 32, 32])
# After layer 4 torch.Size([1, 512, 16, 16])
# After bn torch.Size([1, 1024, 16, 16])
# After layer 6 torch.Size([1, 512, 32, 32])
# After layer 7 torch.Size([1, 256, 64, 64])
# After layer 8 torch.Size([1, 128, 128, 128])
# After layer 9 torch.Size([1, 64, 256, 256])
# Output shape torch.Size([1, 1, 256, 256])

# %% [markdown]
# ## Segmentation
#
# - Image segmentation is the task of partitioning an image, or identifying an object in an image
# - Particular value in medical imaging, highlighting objects of interest
#
# <p align="center">
# <img src="DRIVE/training/images/21_training.png" width="200" title="Image." >
# </p>
# <p align="center">
# <img src="DRIVE/training/1st_manual/21_manual1.png" width="200" title="Image." >
# </p>
#
# - The target image is a binary image, where pixels = 0 are background and pixels = 1 are foreground. We want the network to output a binary image replicating this.

# %%
def get_paths(base_path='DRIVE/'):
    train_im_paths = []
    train_gt_paths = []
    test_im_paths = []
    test_gt_paths = []
    
    for i in range(21, 41):
        train_im_paths.append(base_path + 'training/images/%d_training.tif'%(i))
        train_gt_paths.append(base_path + 'training/1st_manual/%d_manual1.gif'%(i))

    for i in range(1, 21):
        test_im_paths.append(base_path + 'test/images/%d_test.tif'%(i))
        test_gt_paths.append(base_path + 'test/1st_manual/%d_manual1.gif'%(i))
        
    train_paths = [train_im_paths,train_gt_paths]
    test_paths = [test_im_paths,test_gt_paths]
    return train_paths, test_paths

def read_and_resize(im_paths, gt_paths, resize=(256, 256, 1)): 
    imgs = io.imread(im_paths, 1)
    gts = io.imread(gt_paths, 1) 

    imgs = transform.resize(imgs, resize)
    gts = transform.resize(gts, resize) 
        
    return imgs, gts

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, paths):
        # TODO
        # 1. Initialize file paths or a list of file names. 
        self.im_paths = paths[0]
        self.gt_paths = paths[1]
        self.preprocesses = T.Compose([
            T.Resize((256,256)),
            T.ToTensor(),
        ])
        pass
    def __getitem__(self, index):
        # TODO
        # 1. Read one data from file (e.g. using numpy.fromfile, PIL.Image.open).
        image = Image.open(self.im_paths[index])
        label = Image.open(self.gt_paths[index])
        # 2. Preprocess the data (e.g. torchvision.Transform).
        
        image = self.preprocesses(image)
        label = self.preprocesses(label)
        
        #Ensure gt is binary
        label[label>.5] = 1
        label[label<=.5]=0
        # 3. Return a data pair (e.g. image and label).
        return image, label
        
    def __len__(self):
        return len(self.im_paths)
    

train_paths, test_paths = get_paths()
    
custom_dataset = CustomDataset(train_paths)
train_loader = torch.utils.data.DataLoader(dataset=custom_dataset,
                                           batch_size=4, 
                                           shuffle=True)

# %%
print(train_loader)
data_iter = iter(train_loader)
image,label = data_iter.next()
print(image.size())
print(label.size())

label = torch.squeeze(label)
print(label.size())
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x000001DAD806BEE0>
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 1, 256, 256])
# torch.Size([4, 256, 256])

# %%
im,label = custom_dataset[0]
print(im.size())
print(label.size())

plt.figure()
plt.subplot(1,2,1)
plt.imshow(im.permute(1, 2, 0))
plt.subplot(1,2,2)
plt.imshow(label[0,:,:])
# Out:
# torch.Size([3, 256, 256])
# torch.Size([1, 256, 256])

# %%
class CNN(nn.Module):
    def __init__(self,img_size,in_channels,out_channels):
        super(CNN, self).__init__()
        f = [10,20,30,20,10,out_channels]
# Input to conv1 will be image of shape [batch_size,1,img_size,img_size]
        self.conv1 = nn.Sequential(   
            nn.Conv2d(in_channels=in_channels,out_channels=f[0],kernel_size=(3,3),padding=1), 
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size=(2,2)) 
        )
        self.conv2 = nn.Sequential( 
            nn.Conv2d(in_channels=f[0],out_channels=f[1],kernel_size=(3,3),padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2,2)) 
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=f[1],out_channels=f[2],kernel_size=(3,3),padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=f[2],out_channels=f[2],kernel_size=(3,3),padding=1),
            nn.ReLU()
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=f[2],out_channels=f[3],kernel_size=(3,3),padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2))
        
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=f[3],out_channels=f[4],kernel_size=(3,3),padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2))
        
        
        self.conv6 = nn.Sequential(
            nn.Conv2d(in_channels=f[4],out_channels=f[5],kernel_size=(1,1)),
            nn.Sigmoid()
        )
            

    def forward(self, x,plot=False):

        x1 = self.conv1(x)
        x2 = self.conv2(x1)
        x3 = self.conv3(x2)
        x4 = self.conv4(x3)
        x5 = self.conv5(x4)
        x6 = self.conv6(x5)
        
        if plot:
            print('Input shape', x.shape)
            print('After layer 1', x1.shape)
            print('After layer 2', x2.shape)
            print('After layer 3', x3.shape)
            print('After layer 4', x4.shape)
            print('After layer 5', x5.shape)
            print('After layer 6', x6.shape)

        return x6

model = CNN(img_size=256,in_channels=3, out_channels=1)

# %%
learning_rate = 0.001

optimizer = optim.Adam(model.parameters(), lr = learning_rate)   
loss_func = nn.BCELoss()

# %%
from torch.autograd import Variable

num_epochs = 200

def train(num_epochs, model, train_loader):
    
    model.train()
        
    # Train the model
    total_step = len(train_loader)
        
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
            
            # gives batch data, normalize x when iterate train_loader
            b_x = Variable(images)   # batch x
            b_y = Variable(labels)   # batch y
            output = model(b_x)  
            #loss = loss_func(torch.squeeze(output), torch.squeeze(b_y))
            loss = loss_func(output, b_y)
            
            # clear gradients for this training step   
            optimizer.zero_grad()           
            
            # backpropagation, compute gradients 
            loss.backward()                # apply gradients             
            optimizer.step()                
            
            if (i+1) % 2 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                       .format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))               
        
    
    
train(num_epochs, model, train_loader)
# Out:
# Epoch [1/200], Step [2/5], Loss: 0.7448
# Epoch [1/200], Step [4/5], Loss: 0.7383
# Epoch [2/200], Step [2/5], Loss: 0.7179
# Epoch [2/200], Step [4/5], Loss: 0.6947
# Epoch [3/200], Step [2/5], Loss: 0.6050
# Epoch [3/200], Step [4/5], Loss: 0.5168
# Epoch [4/200], Step [2/5], Loss: 0.3837
# Epoch [4/200], Step [4/5], Loss: 0.3975
# Epoch [5/200], Step [2/5], Loss: 0.4166
# Epoch [5/200], Step [4/5], Loss: 0.4228
# Epoch [6/200], Step [2/5], Loss: 0.3613
# Epoch [6/200], Step [4/5], Loss: 0.3872
# Epoch [7/200], Step [2/5], Loss: 0.3759
# Epoch [7/200], Step [4/5], Loss: 0.3565
# Epoch [8/200], Step [2/5], Loss: 0.3675
# Epoch [8/200], Step [4/5], Loss: 0.3458
# Epoch [9/200], Step [2/5], Loss: 0.3167
# Epoch [9/200], Step [4/5], Loss: 0.2895
# Epoch [10/200], Step [2/5], Loss: 0.2917
# Epoch [10/200], Step [4/5], Loss: 0.2972
# Epoch [11/200], Step [2/5], Loss: 0.2795
# Epoch [11/200], Step [4/5], Loss: 0.2619
# Epoch [12/200], Step [2/5], Loss: 0.2758
# Epoch [12/200], Step [4/5], Loss: 0.2687
# Epoch [13/200], Step [2/5], Loss: 0.2570
# Epoch [13/200], Step [4/5], Loss: 0.2550
# Epoch [14/200], Step [2/5], Loss: 0.2701
# Epoch [14/200], Step [4/5], Loss: 0.2651
# Epoch [15/200], Step [2/5], Loss: 0.2403
# Epoch [15/200], Step [4/5], Loss: 0.2431
# Epoch [16/200], Step [2/5], Loss: 0.2553
# Epoch [16/200], Step [4/5], Loss: 0.2391
# Epoch [17/200], Step [2/5], Loss: 0.2443
# Epoch [17/200], Step [4/5], Loss: 0.2418
# Epoch [18/200], Step [2/5], Loss: 0.2550
# Epoch [18/200], Step [4/5], Loss: 0.2485
# Epoch [19/200], Step [2/5], Loss: 0.2591
# Epoch [19/200], Step [4/5], Loss: 0.2545
# Epoch [20/200], Step [2/5], Loss: 0.2406
# Epoch [20/200], Step [4/5], Loss: 0.2349
# Epoch [21/200], Step [2/5], Loss: 0.2482
# Epoch [21/200], Step [4/5], Loss: 0.2377
# Epoch [22/200], Step [2/5], Loss: 0.2452
# Epoch [22/200], Step [4/5], Loss: 0.2398
# Epoch [23/200], Step [2/5], Loss: 0.2601
# Epoch [23/200], Step [4/5], Loss: 0.2330
# Epoch [24/200], Step [2/5], Loss: 0.2467
# Epoch [24/200], Step [4/5], Loss: 0.2430
# Epoch [25/200], Step [2/5], Loss: 0.2554
# Epoch [25/200], Step [4/5], Loss: 0.2560
# Epoch [26/200], Step [2/5], Loss: 0.2450
# Epoch [26/200], Step [4/5], Loss: 0.2516
# Epoch [27/200], Step [2/5], Loss: 0.2526
# Epoch [27/200], Step [4/5], Loss: 0.2391
# Epoch [28/200], Step [2/5], Loss: 0.2421
# Epoch [28/200], Step [4/5], Loss: 0.2589
# Epoch [29/200], Step [2/5], Loss: 0.2341
# Epoch [29/200], Step [4/5], Loss: 0.2560
# Epoch [30/200], Step [2/5], Loss: 0.2496
# Epoch [30/200], Step [4/5], Loss: 0.2519
# Epoch [31/200], Step [2/5], Loss: 0.2298
# Epoch [31/200], Step [4/5], Loss: 0.2468
# Epoch [32/200], Step [2/5], Loss: 0.2620
# Epoch [32/200], Step [4/5], Loss: 0.2583
# Epoch [33/200], Step [2/5], Loss: 0.2352
# Epoch [33/200], Step [4/5], Loss: 0.2463
# Epoch [34/200], Step [2/5], Loss: 0.2429
# Epoch [34/200], Step [4/5], Loss: 0.2336
# Epoch [35/200], Step [2/5], Loss: 0.2448
# Epoch [35/200], Step [4/5], Loss: 0.2446
# Epoch [36/200], Step [2/5], Loss: 0.2490
# Epoch [36/200], Step [4/5], Loss: 0.2428
# Epoch [37/200], Step [2/5], Loss: 0.2597
# Epoch [37/200], Step [4/5], Loss: 0.2505
# Epoch [38/200], Step [2/5], Loss: 0.2322
# Epoch [38/200], Step [4/5], Loss: 0.2528
# Epoch [39/200], Step [2/5], Loss: 0.2238
# Epoch [39/200], Step [4/5], Loss: 0.2458
# Epoch [40/200], Step [2/5], Loss: 0.2175
# Epoch [40/200], Step [4/5], Loss: 0.2428
# Epoch [41/200], Step [2/5], Loss: 0.2464
# Epoch [41/200], Step [4/5], Loss: 0.2374
# Epoch [42/200], Step [2/5], Loss: 0.2381
# Epoch [42/200], Step [4/5], Loss: 0.2452
# Epoch [43/200], Step [2/5], Loss: 0.2274
# Epoch [43/200], Step [4/5], Loss: 0.2546
# Epoch [44/200], Step [2/5], Loss: 0.2338
# Epoch [44/200], Step [4/5], Loss: 0.2481
# Epoch [45/200], Step [2/5], Loss: 0.2317
# Epoch [45/200], Step [4/5], Loss: 0.2520
# Epoch [46/200], Step [2/5], Loss: 0.2670
# Epoch [46/200], Step [4/5], Loss: 0.2529
# Epoch [47/200], Step [2/5], Loss: 0.2596
# Epoch [47/200], Step [4/5], Loss: 0.2407
# Epoch [48/200], Step [2/5], Loss: 0.2411
# Epoch [48/200], Step [4/5], Loss: 0.2709
# Epoch [49/200], Step [2/5], Loss: 0.2474
# Epoch [49/200], Step [4/5], Loss: 0.2424
# Epoch [50/200], Step [2/5], Loss: 0.2418
# Epoch [50/200], Step [4/5], Loss: 0.2734
# Epoch [51/200], Step [2/5], Loss: 0.2696
# Epoch [51/200], Step [4/5], Loss: 0.2631
# Epoch [52/200], Step [2/5], Loss: 0.2360
# Epoch [52/200], Step [4/5], Loss: 0.2375
# Epoch [53/200], Step [2/5], Loss: 0.2442
# Epoch [53/200], Step [4/5], Loss: 0.2370
# Epoch [54/200], Step [2/5], Loss: 0.2520
# Epoch [54/200], Step [4/5], Loss: 0.2463
# Epoch [55/200], Step [2/5], Loss: 0.2434
# Epoch [55/200], Step [4/5], Loss: 0.2500
# Epoch [56/200], Step [2/5], Loss: 0.2461
# Epoch [56/200], Step [4/5], Loss: 0.2491
# Epoch [57/200], Step [2/5], Loss: 0.2475
# Epoch [57/200], Step [4/5], Loss: 0.2645
# Epoch [58/200], Step [2/5], Loss: 0.2502
# Epoch [58/200], Step [4/5], Loss: 0.2357
# Epoch [59/200], Step [2/5], Loss: 0.2506
# Epoch [59/200], Step [4/5], Loss: 0.2511
# Epoch [60/200], Step [2/5], Loss: 0.2640
# Epoch [60/200], Step [4/5], Loss: 0.2338
# Epoch [61/200], Step [2/5], Loss: 0.2471
# Epoch [61/200], Step [4/5], Loss: 0.2508
# Epoch [62/200], Step [2/5], Loss: 0.2402
# Epoch [62/200], Step [4/5], Loss: 0.2505
# Epoch [63/200], Step [2/5], Loss: 0.2450
# Epoch [63/200], Step [4/5], Loss: 0.2487
# Epoch [64/200], Step [2/5], Loss: 0.2316
# Epoch [64/200], Step [4/5], Loss: 0.2619
# Epoch [65/200], Step [2/5], Loss: 0.2436
# Epoch [65/200], Step [4/5], Loss: 0.2547
# Epoch [66/200], Step [2/5], Loss: 0.2530
# Epoch [66/200], Step [4/5], Loss: 0.2258
# Epoch [67/200], Step [2/5], Loss: 0.2412
# Epoch [67/200], Step [4/5], Loss: 0.2420
# Epoch [68/200], Step [2/5], Loss: 0.2511
# Epoch [68/200], Step [4/5], Loss: 0.2358
# Epoch [69/200], Step [2/5], Loss: 0.2271
# Epoch [69/200], Step [4/5], Loss: 0.2538
# Epoch [70/200], Step [2/5], Loss: 0.2334
# Epoch [70/200], Step [4/5], Loss: 0.2543
# Epoch [71/200], Step [2/5], Loss: 0.2474
# Epoch [71/200], Step [4/5], Loss: 0.2332
# Epoch [72/200], Step [2/5], Loss: 0.2444
# Epoch [72/200], Step [4/5], Loss: 0.2613
# Epoch [73/200], Step [2/5], Loss: 0.2456
# Epoch [73/200], Step [4/5], Loss: 0.2702
# Epoch [74/200], Step [2/5], Loss: 0.2343
# Epoch [74/200], Step [4/5], Loss: 0.2619
# Epoch [75/200], Step [2/5], Loss: 0.2557
# Epoch [75/200], Step [4/5], Loss: 0.2659
# Epoch [76/200], Step [2/5], Loss: 0.2498
# Epoch [76/200], Step [4/5], Loss: 0.2489
# Epoch [77/200], Step [2/5], Loss: 0.2589
# Epoch [77/200], Step [4/5], Loss: 0.2328
# Epoch [78/200], Step [2/5], Loss: 0.2456
# Epoch [78/200], Step [4/5], Loss: 0.2627
# Epoch [79/200], Step [2/5], Loss: 0.2268
# Epoch [79/200], Step [4/5], Loss: 0.2542
# Epoch [80/200], Step [2/5], Loss: 0.2369
# Epoch [80/200], Step [4/5], Loss: 0.2361
# Epoch [81/200], Step [2/5], Loss: 0.2588
# Epoch [81/200], Step [4/5], Loss: 0.2678
# Epoch [82/200], Step [2/5], Loss: 0.2575
# Epoch [82/200], Step [4/5], Loss: 0.2380
# Epoch [83/200], Step [2/5], Loss: 0.2374
# Epoch [83/200], Step [4/5], Loss: 0.2297
# Epoch [84/200], Step [2/5], Loss: 0.2539
# Epoch [84/200], Step [4/5], Loss: 0.2362
# Epoch [85/200], Step [2/5], Loss: 0.2357
# Epoch [85/200], Step [4/5], Loss: 0.2488
# Epoch [86/200], Step [2/5], Loss: 0.2324
# Epoch [86/200], Step [4/5], Loss: 0.2392
# Epoch [87/200], Step [2/5], Loss: 0.2379
# Epoch [87/200], Step [4/5], Loss: 0.2567
# Epoch [88/200], Step [2/5], Loss: 0.2412
# Epoch [88/200], Step [4/5], Loss: 0.2367
# Epoch [89/200], Step [2/5], Loss: 0.2575
# Epoch [89/200], Step [4/5], Loss: 0.2362
# Epoch [90/200], Step [2/5], Loss: 0.2628
# Epoch [90/200], Step [4/5], Loss: 0.2586
# Epoch [91/200], Step [2/5], Loss: 0.2483
# Epoch [91/200], Step [4/5], Loss: 0.2379
# Epoch [92/200], Step [2/5], Loss: 0.2487
# Epoch [92/200], Step [4/5], Loss: 0.2191
# Epoch [93/200], Step [2/5], Loss: 0.2665
# Epoch [93/200], Step [4/5], Loss: 0.2414
# Epoch [94/200], Step [2/5], Loss: 0.2335
# Epoch [94/200], Step [4/5], Loss: 0.2390
# Epoch [95/200], Step [2/5], Loss: 0.2373
# Epoch [95/200], Step [4/5], Loss: 0.2206
# Epoch [96/200], Step [2/5], Loss: 0.2222
# Epoch [96/200], Step [4/5], Loss: 0.2507
# Epoch [97/200], Step [2/5], Loss: 0.2418
# Epoch [97/200], Step [4/5], Loss: 0.2459
# Epoch [98/200], Step [2/5], Loss: 0.2296
# Epoch [98/200], Step [4/5], Loss: 0.2447
# Epoch [99/200], Step [2/5], Loss: 0.2643
# Epoch [99/200], Step [4/5], Loss: 0.2347
# Epoch [100/200], Step [2/5], Loss: 0.2465
# Epoch [100/200], Step [4/5], Loss: 0.2366
# Epoch [101/200], Step [2/5], Loss: 0.2252
# Epoch [101/200], Step [4/5], Loss: 0.2591
# Epoch [102/200], Step [2/5], Loss: 0.2361
# Epoch [102/200], Step [4/5], Loss: 0.2393
# Epoch [103/200], Step [2/5], Loss: 0.2513
# Epoch [103/200], Step [4/5], Loss: 0.2462
# Epoch [104/200], Step [2/5], Loss: 0.2285
# Epoch [104/200], Step [4/5], Loss: 0.2823
# Epoch [105/200], Step [2/5], Loss: 0.2392
# Epoch [105/200], Step [4/5], Loss: 0.2454
# Epoch [106/200], Step [2/5], Loss: 0.2407
# Epoch [106/200], Step [4/5], Loss: 0.2465
# Epoch [107/200], Step [2/5], Loss: 0.2487
# Epoch [107/200], Step [4/5], Loss: 0.2442
# Epoch [108/200], Step [2/5], Loss: 0.2412
# Epoch [108/200], Step [4/5], Loss: 0.2652
# Epoch [109/200], Step [2/5], Loss: 0.2382
# Epoch [109/200], Step [4/5], Loss: 0.2499
# Epoch [110/200], Step [2/5], Loss: 0.2420
# Epoch [110/200], Step [4/5], Loss: 0.2448
# Epoch [111/200], Step [2/5], Loss: 0.2363
# Epoch [111/200], Step [4/5], Loss: 0.2338
# Epoch [112/200], Step [2/5], Loss: 0.2625
# Epoch [112/200], Step [4/5], Loss: 0.2457
# Epoch [113/200], Step [2/5], Loss: 0.2455
# Epoch [113/200], Step [4/5], Loss: 0.2317
# Epoch [114/200], Step [2/5], Loss: 0.2452
# Epoch [114/200], Step [4/5], Loss: 0.2273
# Epoch [115/200], Step [2/5], Loss: 0.2523
# Epoch [115/200], Step [4/5], Loss: 0.2538
# Epoch [116/200], Step [2/5], Loss: 0.2581
# Epoch [116/200], Step [4/5], Loss: 0.2331
# Epoch [117/200], Step [2/5], Loss: 0.2347
# Epoch [117/200], Step [4/5], Loss: 0.2521
# Epoch [118/200], Step [2/5], Loss: 0.2582
# Epoch [118/200], Step [4/5], Loss: 0.2456
# Epoch [119/200], Step [2/5], Loss: 0.2203
# Epoch [119/200], Step [4/5], Loss: 0.2618
# Epoch [120/200], Step [2/5], Loss: 0.2377
# Epoch [120/200], Step [4/5], Loss: 0.2563
# Epoch [121/200], Step [2/5], Loss: 0.2513
# Epoch [121/200], Step [4/5], Loss: 0.2289
# Epoch [122/200], Step [2/5], Loss: 0.2581
# Epoch [122/200], Step [4/5], Loss: 0.2350
# Epoch [123/200], Step [2/5], Loss: 0.2499
# Epoch [123/200], Step [4/5], Loss: 0.2561
# Epoch [124/200], Step [2/5], Loss: 0.2253
# Epoch [124/200], Step [4/5], Loss: 0.2527
# Epoch [125/200], Step [2/5], Loss: 0.2317
# Epoch [125/200], Step [4/5], Loss: 0.2269
# Epoch [126/200], Step [2/5], Loss: 0.2355
# Epoch [126/200], Step [4/5], Loss: 0.2361
# Epoch [127/200], Step [2/5], Loss: 0.2331
# Epoch [127/200], Step [4/5], Loss: 0.2690
# Epoch [128/200], Step [2/5], Loss: 0.2467
# Epoch [128/200], Step [4/5], Loss: 0.2316
# Epoch [129/200], Step [2/5], Loss: 0.2453
# Epoch [129/200], Step [4/5], Loss: 0.2376
# Epoch [130/200], Step [2/5], Loss: 0.2625
# Epoch [130/200], Step [4/5], Loss: 0.2318
# Epoch [131/200], Step [2/5], Loss: 0.2167
# Epoch [131/200], Step [4/5], Loss: 0.2514
# Epoch [132/200], Step [2/5], Loss: 0.2436
# Epoch [132/200], Step [4/5], Loss: 0.2326
# Epoch [133/200], Step [2/5], Loss: 0.2411
# Epoch [133/200], Step [4/5], Loss: 0.2229
# Epoch [134/200], Step [2/5], Loss: 0.2433
# Epoch [134/200], Step [4/5], Loss: 0.2415
# Epoch [135/200], Step [2/5], Loss: 0.2594
# Epoch [135/200], Step [4/5], Loss: 0.2594
# Epoch [136/200], Step [2/5], Loss: 0.2249
# Epoch [136/200], Step [4/5], Loss: 0.2381
# Epoch [137/200], Step [2/5], Loss: 0.2415
# Epoch [137/200], Step [4/5], Loss: 0.2498
# Epoch [138/200], Step [2/5], Loss: 0.2279
# Epoch [138/200], Step [4/5], Loss: 0.2282
# Epoch [139/200], Step [2/5], Loss: 0.2297
# Epoch [139/200], Step [4/5], Loss: 0.2270
# Epoch [140/200], Step [2/5], Loss: 0.2376
# Epoch [140/200], Step [4/5], Loss: 0.2470
# Epoch [141/200], Step [2/5], Loss: 0.2209
# Epoch [141/200], Step [4/5], Loss: 0.2370
# Epoch [142/200], Step [2/5], Loss: 0.2229
# Epoch [142/200], Step [4/5], Loss: 0.2224
# Epoch [143/200], Step [2/5], Loss: 0.2392
# Epoch [143/200], Step [4/5], Loss: 0.2199
# Epoch [144/200], Step [2/5], Loss: 0.2361
# Epoch [144/200], Step [4/5], Loss: 0.2086
# Epoch [145/200], Step [2/5], Loss: 0.2223
# Epoch [145/200], Step [4/5], Loss: 0.2436
# Epoch [146/200], Step [2/5], Loss: 0.2155
# Epoch [146/200], Step [4/5], Loss: 0.2605
# Epoch [147/200], Step [2/5], Loss: 0.2184
# Epoch [147/200], Step [4/5], Loss: 0.2706
# Epoch [148/200], Step [2/5], Loss: 0.2409
# Epoch [148/200], Step [4/5], Loss: 0.2485
# Epoch [149/200], Step [2/5], Loss: 0.2133
# Epoch [149/200], Step [4/5], Loss: 0.2421
# Epoch [150/200], Step [2/5], Loss: 0.2426
# Epoch [150/200], Step [4/5], Loss: 0.2227
# Epoch [151/200], Step [2/5], Loss: 0.2463
# Epoch [151/200], Step [4/5], Loss: 0.2424
# Epoch [152/200], Step [2/5], Loss: 0.2173
# Epoch [152/200], Step [4/5], Loss: 0.2562
# Epoch [153/200], Step [2/5], Loss: 0.2158
# Epoch [153/200], Step [4/5], Loss: 0.2378
# Epoch [154/200], Step [2/5], Loss: 0.2140
# Epoch [154/200], Step [4/5], Loss: 0.2351
# Epoch [155/200], Step [2/5], Loss: 0.2471
# Epoch [155/200], Step [4/5], Loss: 0.2174
# Epoch [156/200], Step [2/5], Loss: 0.2250
# Epoch [156/200], Step [4/5], Loss: 0.2184
# Epoch [157/200], Step [2/5], Loss: 0.2379
# Epoch [157/200], Step [4/5], Loss: 0.2109
# Epoch [158/200], Step [2/5], Loss: 0.2149
# Epoch [158/200], Step [4/5], Loss: 0.2150
# Epoch [159/200], Step [2/5], Loss: 0.2530
# Epoch [159/200], Step [4/5], Loss: 0.2065
# Epoch [160/200], Step [2/5], Loss: 0.2175
# Epoch [160/200], Step [4/5], Loss: 0.2712
# Epoch [161/200], Step [2/5], Loss: 0.2197
# Epoch [161/200], Step [4/5], Loss: 0.2393
# Epoch [162/200], Step [2/5], Loss: 0.2192
# Epoch [162/200], Step [4/5], Loss: 0.2013
# Epoch [163/200], Step [2/5], Loss: 0.2374
# Epoch [163/200], Step [4/5], Loss: 0.2143
# Epoch [164/200], Step [2/5], Loss: 0.2163
# Epoch [164/200], Step [4/5], Loss: 0.2277
# Epoch [165/200], Step [2/5], Loss: 0.2474
# Epoch [165/200], Step [4/5], Loss: 0.2575
# Epoch [166/200], Step [2/5], Loss: 0.2630
# Epoch [166/200], Step [4/5], Loss: 0.2366
# Epoch [167/200], Step [2/5], Loss: 0.2341
# Epoch [167/200], Step [4/5], Loss: 0.2185
# Epoch [168/200], Step [2/5], Loss: 0.2243
# Epoch [168/200], Step [4/5], Loss: 0.2350
# Epoch [169/200], Step [2/5], Loss: 0.2030
# Epoch [169/200], Step [4/5], Loss: 0.2387
# Epoch [170/200], Step [2/5], Loss: 0.2242
# Epoch [170/200], Step [4/5], Loss: 0.1932
# Epoch [171/200], Step [2/5], Loss: 0.1972
# Epoch [171/200], Step [4/5], Loss: 0.2340
# Epoch [172/200], Step [2/5], Loss: 0.2260
# Epoch [172/200], Step [4/5], Loss: 0.2196
# Epoch [173/200], Step [2/5], Loss: 0.2166
# Epoch [173/200], Step [4/5], Loss: 0.2303
# Epoch [174/200], Step [2/5], Loss: 0.2012
# Epoch [174/200], Step [4/5], Loss: 0.1943
# Epoch [175/200], Step [2/5], Loss: 0.2223
# Epoch [175/200], Step [4/5], Loss: 0.1930
# Epoch [176/200], Step [2/5], Loss: 0.2014
# Epoch [176/200], Step [4/5], Loss: 0.2160
# Epoch [177/200], Step [2/5], Loss: 0.2001
# Epoch [177/200], Step [4/5], Loss: 0.2108
# Epoch [178/200], Step [2/5], Loss: 0.1893
# Epoch [178/200], Step [4/5], Loss: 0.2020
# Epoch [179/200], Step [2/5], Loss: 0.1912
# Epoch [179/200], Step [4/5], Loss: 0.2401
# Epoch [180/200], Step [2/5], Loss: 0.2182
# Epoch [180/200], Step [4/5], Loss: 0.1904
# Epoch [181/200], Step [2/5], Loss: 0.1993
# Epoch [181/200], Step [4/5], Loss: 0.2232
# Epoch [182/200], Step [2/5], Loss: 0.2024
# Epoch [182/200], Step [4/5], Loss: 0.2110
# Epoch [183/200], Step [2/5], Loss: 0.1753
# Epoch [183/200], Step [4/5], Loss: 0.1995
# Epoch [184/200], Step [2/5], Loss: 0.2114
# Epoch [184/200], Step [4/5], Loss: 0.1982
# Epoch [185/200], Step [2/5], Loss: 0.2388
# Epoch [185/200], Step [4/5], Loss: 0.2043
# Epoch [186/200], Step [2/5], Loss: 0.1907
# Epoch [186/200], Step [4/5], Loss: 0.2093
# Epoch [187/200], Step [2/5], Loss: 0.2274
# Epoch [187/200], Step [4/5], Loss: 0.2139
# Epoch [188/200], Step [2/5], Loss: 0.1972
# Epoch [188/200], Step [4/5], Loss: 0.1911
# Epoch [189/200], Step [2/5], Loss: 0.2208
# Epoch [189/200], Step [4/5], Loss: 0.2131
# Epoch [190/200], Step [2/5], Loss: 0.1975
# Epoch [190/200], Step [4/5], Loss: 0.2000
# Epoch [191/200], Step [2/5], Loss: 0.1875
# Epoch [191/200], Step [4/5], Loss: 0.1974
# Epoch [192/200], Step [2/5], Loss: 0.1887
# Epoch [192/200], Step [4/5], Loss: 0.2023
# Epoch [193/200], Step [2/5], Loss: 0.1889
# Epoch [193/200], Step [4/5], Loss: 0.1879
# Epoch [194/200], Step [2/5], Loss: 0.2016
# Epoch [194/200], Step [4/5], Loss: 0.1810
# Epoch [195/200], Step [2/5], Loss: 0.1819
# Epoch [195/200], Step [4/5], Loss: 0.1807
# Epoch [196/200], Step [2/5], Loss: 0.1812
# Epoch [196/200], Step [4/5], Loss: 0.1917
# Epoch [197/200], Step [2/5], Loss: 0.1720
# Epoch [197/200], Step [4/5], Loss: 0.2039
# Epoch [198/200], Step [2/5], Loss: 0.1887
# Epoch [198/200], Step [4/5], Loss: 0.1910
# Epoch [199/200], Step [2/5], Loss: 0.1864
# Epoch [199/200], Step [4/5], Loss: 0.2032
# Epoch [200/200], Step [2/5], Loss: 0.1882
# Epoch [200/200], Step [4/5], Loss: 0.1917

# %%
test_dataset = CustomDataset(test_paths)
train_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=4, 
                                           shuffle=True)
dataset = test_dataset

with torch.no_grad():
    figure = plt.figure(figsize=(10, 8))
    rows = 2
    for i in range(0, rows):
        sample_idx = torch.randint(len(dataset), size=(1,)).item()
        img, label = dataset[sample_idx]
        b_x = img.unsqueeze(0)
        output = model(b_x)

        figure.add_subplot(rows, 3, 3*i + 1)
        plt.axis("off")
        plt.imshow(img.permute(1,2,0))
        plt.title("image")
        figure.add_subplot(rows, 3, 3*i + 2)
        plt.axis("off")
        plt.imshow(torch.squeeze(output), cmap="gray")
        plt.title("model output")
        figure.add_subplot(rows, 3, 3*i + 3)
        plt.axis("off")
        plt.imshow(torch.squeeze(label), cmap="gray")
        plt.title("ground truth")
    plt.show()

# %% [markdown]
# ## 5. Image Denoising with MNIST
#
# - Problem setup: Suppose we have an observed noisy image $x$, and we wish to recover a clean version of the image, $u$. We model using additive gaussian noise: $x = u + \epsilon$ where $\epsilon$ is the noise.
# - Let us set the data up, by extracting the MNIST images and adding gaussian noise to them.

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

train_data = datasets.MNIST(
    root = 'data',
    train = True,                         
    transform = ToTensor(), 
    download = True)
test_data = datasets.MNIST(
    root = 'data', 
    train = False, 
    transform = ToTensor()
)

# %%
train_imgs = train_data.data
print(train_imgs.shape)
train_imgs = train_imgs.numpy()
# store the clean images before adding noise
train_imgs0 = train_imgs/255.0

test_imgs = test_data.data
test_imgs = test_imgs.numpy()
test_imgs0 = test_imgs/255.0

sigma = 70/255.0 # noise level
train_imgs = (train_imgs/255.0 + np.random.normal(0,sigma,train_imgs.shape)).clip(0,1)
test_imgs = (test_imgs/255.0 + np.random.normal(0,sigma,test_imgs.shape)).clip(0,1)


fig = plt.figure()
plt.subplot(1,2,1)
plt.imshow(train_imgs0[0],cmap='gray')
plt.subplot(1,2,2)
plt.imshow(train_imgs[0],cmap='gray')
plt.show()
# Out:
# torch.Size([60000, 28, 28])

# %%
model = CNN(img_size=28, in_channels=1, out_channels = 1).to(device)

# %%
learning_rate = 0.001

optimizer = optim.Adam(model.parameters(), lr = learning_rate)   
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )

# %%
total_step = len(train_imgs)
print(total_step)
train_imgs.shape
# Out:
# 60000
# (60000, 28, 28)

# %%
loaders = {
    'train' : torch.utils.data.DataLoader(train_imgs, 
                                          batch_size=100, 
                                          shuffle=True, 
                                          num_workers=1),
    
    'test'  : torch.utils.data.DataLoader(test_imgs, 
                                          batch_size=100, 
                                          shuffle=True, 
                                          num_workers=1),
}
loaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x1da80becfd0>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x1da80b2e430>}

# %% [markdown]
# ## Loss Function:
#
# - In our denoising setup we assume no label. Our dataset consists of only observed noisy images, i.e. $\mathcal{D} = \{ \mathbf{x}_i \in \mathbb{R}^{h \times w} \}_{k=1}^n$. This approach (not using labels) is known as **unsupervised learning**.
#
# - We will implement a classic denoising model, which is composed of two terms:
# $$ \mathcal{L}(\theta) = \sum_{k=1}^n || \nabla f(\mathbf{x}_i;\theta) ||_2 + \frac{\lambda}{2} || f(\mathbf{x}_i; \theta) - \mathbf{x}_i ||_2^2 , $$
# - where $\lambda>0$ is a parameter which we hand tune according to the strength of noise. If we have a large $\lambda$, the second term is more dominiant and our network output will be matched more closely to the input (i.e. $f(\mathbf{x}_i ; \theta) \approx \mathbf{x}_i$). If $\lambda$ is small, the first term will be more dominant and more smoothing will occur.

# %%
def up_shift(f):
    g = torch.zeros_like(f)
    g[:-1, :] = f[1:, :]
    g[-1, :] = f[-1, :]
    return g

def down_shift(f):
    g = torch.zeros_like(f)
    g[1:, :] = f[:-1, :]
    g[0, :] = f[0, :]
    return g

def left_shift(f):
    g = torch.zeros_like(f)
    g[:, :-1] = f[:, 1:]
    g[:, -1] = f[:, -1]
    return g

def right_shift(f):
    g = torch.zeros_like(f)
    g[:, 1:] = f[:, :-1]
    g[:, 0] = f[:, 0]
    return g


def grad(f):
    f_x = (left_shift(f) - right_shift(f))/2
    f_y = (down_shift(f) - up_shift(f))/2
    
    return torch.sqrt(f_x**2 + f_y**2 + 1e-7)

class denoising_loss(nn.Module):
    def __init__(self):
        super().__init__()
        
    def forward(self, denoised, noisy, lambdaP):
        
        TV_term = grad(denoised)
        
        Fit_Term = (lambdaP/2)*(denoised-noisy)**2
        
        loss = TV_term + Fit_Term

        return loss.mean()

# %%
from torch.autograd import Variable
num_epochs = 10
lambdaP = 8
loss_func = denoising_loss()
def train(num_epochs, model, loaders):
    
    model.train()
        
    # Train the model
    total_step = len(loaders['train'])
        
    for epoch in range(num_epochs):
        for i, images in enumerate(loaders['train']):
            
            # gives batch data, normalize x when iterate train_loader
            b_x = Variable(images, requires_grad=True).to(device)   # batch x. b_x is of shape [100,28,28]
            #print(b_x.shape)
            b_x = b_x.unsqueeze(1) # make dimensions [100,1,28,28], rather than [100,28,28]
            #print(b_x.shape)
            output = model(b_x.float())  

            #print(output.shape)
            loss = loss_func(output,b_x,lambdaP)
                        
            # clear gradients for this training step   
            optimizer.zero_grad()           
            
            # backpropagation, compute gradients 
            loss.backward()                # apply gradients             
            optimizer.step()                
            
            if (i+1) % 100 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                       .format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))               
        
    
    
train(num_epochs, model, loaders)
# Out:
# Epoch [1/10], Step [100/600], Loss: 0.3206
# Epoch [1/10], Step [200/600], Loss: 0.2768
# Epoch [1/10], Step [300/600], Loss: 0.2387
# Epoch [1/10], Step [400/600], Loss: 0.2386
# Epoch [1/10], Step [500/600], Loss: 0.2244
# Epoch [1/10], Step [600/600], Loss: 0.2241
# Epoch [2/10], Step [100/600], Loss: 0.2196
# Epoch [2/10], Step [200/600], Loss: 0.2194
# Epoch [2/10], Step [300/600], Loss: 0.2158
# Epoch [2/10], Step [400/600], Loss: 0.2159
# Epoch [2/10], Step [500/600], Loss: 0.2183
# Epoch [2/10], Step [600/600], Loss: 0.2152
# Epoch [3/10], Step [100/600], Loss: 0.2107
# Epoch [3/10], Step [200/600], Loss: 0.2116
# Epoch [3/10], Step [300/600], Loss: 0.2115
# Epoch [3/10], Step [400/600], Loss: 0.2160
# Epoch [3/10], Step [500/600], Loss: 0.2108
# Epoch [3/10], Step [600/600], Loss: 0.2101
# Epoch [4/10], Step [100/600], Loss: 0.2113
# Epoch [4/10], Step [200/600], Loss: 0.2184
# Epoch [4/10], Step [300/600], Loss: 0.2077
# Epoch [4/10], Step [400/600], Loss: 0.2110
# Epoch [4/10], Step [500/600], Loss: 0.2120
# Epoch [4/10], Step [600/600], Loss: 0.2086
# Epoch [5/10], Step [100/600], Loss: 0.2061
# Epoch [5/10], Step [200/600], Loss: 0.2172
# Epoch [5/10], Step [300/600], Loss: 0.2107
# Epoch [5/10], Step [400/600], Loss: 0.2156
# Epoch [5/10], Step [500/600], Loss: 0.2060
# Epoch [5/10], Step [600/600], Loss: 0.2104
# Epoch [6/10], Step [100/600], Loss: 0.2102
# Epoch [6/10], Step [200/600], Loss: 0.2085
# Epoch [6/10], Step [300/600], Loss: 0.2115
# Epoch [6/10], Step [400/600], Loss: 0.2151
# Epoch [6/10], Step [500/600], Loss: 0.2113
# Epoch [6/10], Step [600/600], Loss: 0.2110
# Epoch [7/10], Step [100/600], Loss: 0.2081
# Epoch [7/10], Step [200/600], Loss: 0.2077
# Epoch [7/10], Step [300/600], Loss: 0.2127
# Epoch [7/10], Step [400/600], Loss: 0.2101
# Epoch [7/10], Step [500/600], Loss: 0.2082
# Epoch [7/10], Step [600/600], Loss: 0.2066
# Epoch [8/10], Step [100/600], Loss: 0.2083
# Epoch [8/10], Step [200/600], Loss: 0.2080
# Epoch [8/10], Step [300/600], Loss: 0.2075
# Epoch [8/10], Step [400/600], Loss: 0.2056
# Epoch [8/10], Step [500/600], Loss: 0.2114
# Epoch [8/10], Step [600/600], Loss: 0.2115
# Epoch [9/10], Step [100/600], Loss: 0.2046
# Epoch [9/10], Step [200/600], Loss: 0.2090
# Epoch [9/10], Step [300/600], Loss: 0.2045
# Epoch [9/10], Step [400/600], Loss: 0.2118
# Epoch [9/10], Step [500/600], Loss: 0.2082
# Epoch [9/10], Step [600/600], Loss: 0.2072
# Epoch [10/10], Step [100/600], Loss: 0.2102
# Epoch [10/10], Step [200/600], Loss: 0.2083
# Epoch [10/10], Step [300/600], Loss: 0.2085
# Epoch [10/10], Step [400/600], Loss: 0.2086
# Epoch [10/10], Step [500/600], Loss: 0.2040
# Epoch [10/10], Step [600/600], Loss: 0.2083

# %%
with torch.no_grad():
    #Plot multiple
    figure = plt.figure(figsize=(15, 12))
    cols, rows =4,4
    for i in range(1, int((cols * rows)/2) + 1):
        sample_idx = torch.randint(len(test_imgs), size=(1,)).item()
        noisy, clean = test_imgs[sample_idx], test_imgs0[sample_idx]
        noisy = noisy[np.newaxis,np.newaxis,:,:]
        b_x = torch.from_numpy(noisy).float()
        b_x = b_x.to(device)
        output = model(b_x)
        output = output.cpu()

        figure.add_subplot(rows,cols,2*i - 1)
        plt.title('noisy input')
        plt.axis("off")
        plt.imshow(noisy.squeeze(),cmap="gray")

        figure.add_subplot(rows,cols,2*i)
        plt.title('net denoised')
        plt.axis("off")
        plt.imshow(output.squeeze(),cmap="gray")

    plt.show()

# %% [markdown]
# ## Homework
#
# - Try training the segmentation problem again with DICE loss function.
# - The DICE coefficient is a measure of how well two sets coincide with one another, i.e. how well two segmentation results are similar. We use the output of our network, $u$, and the ground truth, $GT$, to measure performance.
# $$ DICE(u,GT) = \frac{ 2 \cdot | u \cdot GT |}{|u| + |GT|} $$
# <p align="center">
# <img src="dice.png" width="250" title="DICE." >
# </p>
#
# - A score of 1 is a perfect match, whereas a score of 0 is the opposite. We want a score of 1 in segmentation.
# - To use this in a loss function, the loss function looks like:
# $$ DICELOSS(u,GT) = 1 - DICE(u,GT) $$

# %%
class DiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(DiceLoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        
        ###comment out if your model contains a sigmoid or equivalent activation layer
        #inputs = F.sigmoid(inputs)       
        
        ###flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        
        intersection = (inputs * targets).sum()                            
        dice = (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)  
        
        return 1 - dice
